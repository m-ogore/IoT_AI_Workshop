# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pickle

# %%
data = pd.read_csv('Housing.csv')

# %%
data.tail(-5)
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 5    10850000   7500         3          3        1      yes        no
# 6    10150000   8580         4          3        4      yes        no
# 7    10150000  16200         5          3        2      yes        no
# 8     9870000   8100         4          1        2      yes       yes
# 9     9800000   5750         3          2        4      yes       yes
# ..        ...    ...       ...        ...      ...      ...       ...
# 540   1820000   3000         2          1        1      yes        no
# 541   1767150   2400         3          1        1       no        no
# 542   1750000   3620         2          1        1      yes        no
# 543   1750000   2910         3          1        1       no        no
# 544   1750000   3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
non_columns=['mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
        'prefarea', 'furnishingstatus']
data_categorical = data

# %%
data_categorical.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
for column in non_columns:
    data_categorical = pd.get_dummies(data_categorical, columns=column)
    #data_categorical.drop(column)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 for column in non_columns:
# ----> 2     data_categorical = pd.get_dummies(data_categorical, columns=[column])
#       3     #data_categorical.drop(column)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/encoding.py:164, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     162     raise TypeError("Input must be a list-like for parameter `columns`")
#     163 else:
# --> 164     data_to_encode = data[columns]
#     166 # validate prefixes and separator to avoid silently dropping cols
#     167 def check_len(item, name: str):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# ...

# %%
data_categorical = pd.get_dummies(data, columns=['mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
        'prefarea', 'furnishingstatus'])

# %%
data_categorical.drop('mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
        'prefarea', 'furnishingstatus', axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data_categorical.drop('mainroad',
#       2        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#       3         'prefarea', 'furnishingstatus', axis=1)
#
# TypeError: DataFrame.drop() takes from 1 to 2 positional arguments but 8 positional arguments (and 1 keyword-only argument) were given

# %%
data_categorical.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  parking  mainroad_no  \
# 0  13300000  7420         4          2        3        2        False
# 1  12250000  8960         4          4        4        3        False
# 2  12250000  9960         3          2        2        2        False
# 3  12215000  7500         4          2        2        3        False
# 4  11410000  7420         4          1        2        2        False
#
#    mainroad_yes  guestroom_no  guestroom_yes  ...  basement_yes  \
# 0          True          True          False  ...         False
# 1          True          True          False  ...         False
# 2          True          True          False  ...          True
# 3          True          True          False  ...          True
# 4          True         False           True  ...          True
#
#    hotwaterheating_no  hotwaterheating_yes  airconditioning_no  \
# 0                True                False               False
# ...

# %%
data.to_csv("numerical.csv")

# %%
X = data.drop(columns=['price'])

# %%
Y = data['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

# %%
pickle.dump(model, open('house_predict_model.pkl','wb'))

# %%
import numpy as np
x_test = np.array(X_test)
print(np.array(X_test))
y_test = np.array(y_test)
print(np.array(y_test))
# Out:
# [[3420 4 2 ... False True False]
#  [4046 3 1 ... False True False]
#  [8080 3 1 ... False True False]
#  ...
#  [6360 3 1 ... True False False]
#  [4000 3 2 ... False True False]
#  [6600 2 2 ... True False False]]
# [ 4893000  4165000  3920000  3773000  4956000  3850000  3633000  7035000
#   6650000  3605000  6475000  3430000  4445000 11410000  6107500  7420000
#   1767150  3710000  6440000  6650000  4900000  8400000  3353000  7420000
#   3220000  3255000  3150000  4690000  4480000  4025000  4900000  3087000
#   4060000  3465000  3290000  5425000  2380000  4025000  4893000  4585000
#   5460000  4165000  1890000  3745000  5215000  4515000  3360000  2485000
#   4375000  5950000  4130000  3500000  4690000  6083000  4340000  2310000
#   5565000  4753000  4900000  3118850  4200000  3500000  7840000  3493000
#   6475000  4970000  2450000  3150000  4403000  1750000  4200000  2408000
#   9681000  2590000  2940000  4473000  7560000  4480000  3500000  7980000
# ...

# %%
model = pickle.load(open('house_predict_model.pkl','rb'))
predicted_price = model.predict(X_test)

print(predicted_price[0])
# Out:
# 6508327.030970767

# %%
expensive = pd.read_csv()
cheap
moderate
